# %% [markdown]
# ## Notebook for calculating various molecular desciptors

# %%
# Imports
from rdkit import Chem, RDLogger
import os
from mordred import Calculator, descriptors
import pandas as pd
from more_itertools import chunked
from tqdm.notebook import tqdm
# Capturing RDKit errors
from io import StringIO
import sys
Chem.WrapLogs()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
RDLogger.DisableLog('rdApp.*')

# %%
def mol2_to_mol(file=None, sanitize=True):
    mols=[]
    with open(file, 'r') as f:
        line =f.readline()
        while not f.tell() == os.fstat(f.fileno()).st_size:
            if line.startswith("@<TRIPOS>MOLECULE"):
                mol = []
                mol.append(line)
                line = f.readline()
                while not line.startswith("@<TRIPOS>MOLECULE"):
                    mol.append(line)
                    line = f.readline()
                    if f.tell() == os.fstat(f.fileno()).st_size:
                        mol.append(line)
                        break
                mol[-1] = mol[-1].rstrip() # removes blank line at file end
                block = ",".join(mol).replace(',','')
                m=Chem.MolFromMol2Block(block, sanitize=sanitize)
            if m is not None:
                mols.append(m)
    return(mols)

# %%
mols = mol2_to_mol('../small_molecule_search.mol2')
# Out:
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:39] Explicit valence for atom # 5 C, 7, is greater than permitted
# RDKit WARNING: [16:04:39] sanitise [16:04:39] 01: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit WARNING: [16:04:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:39] Can't kekulize mol.  Unkekulized atoms: 0 1 2 4 6 7
# RDKit ERROR:
# RDKit WARNING: [16:04:39] sanitise [16:04:39] 01: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:39] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6 7
# RDKit ERROR:
# RDKit WARNING: [16:04:39] sanitise [16:04:39] 01: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit WARNING: [16:04:39] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] Warning - O.co2 with degree >1.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:39] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:40] Explicit valence for atom # 0 C, 6, is greater than permitted
# RDKit WARNING: [16:04:40] sanitise [16:04:40] 01: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:40] Explicit valence for atom # 12 C, 6, is greater than permitted
# RDKit WARNING: [16:04:40] sanitise [16:04:40] 01: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:40] Explicit valence for atom # 0 C, 6, is greater than permitted
# RDKit WARNING: [16:04:40] sanitise [16:04:40] 01: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:40] Explicit valence for atom # 3 C, 5, is greater than permitted
# RDKit WARNING: [16:04:40] sanitise [16:04:40] 01: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: warning - aromatic N with 3 aromatic bonds - skipping charge guess for this atom
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:40] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# ...
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:51] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 0 C, 5, is greater than permitted
# RDKit ERROR: [16:04:52] Explicit valence for atom # 2 C, 6, is greater than permitted
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:52] Can't kekulize mol.  Unkekulized atoms: 1 2 3 9 10
# RDKit ERROR:
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: warning - O.co2 with non C.2 or S.o2 neighbor.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 1 C, 5, is greater than permitted
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 2 C, 5, is greater than permitted
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 1 C, 6, is greater than permitted
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 2 C, 6, is greater than permitted
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:52] Can't kekulize mol.  Unkekulized atoms: 0 3 4
# RDKit ERROR:
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 1 C, 6, is greater than permitted
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 2 C, 6, is greater than permitted
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit WARNING: [16:04:52] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:52] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5
# RDKit ERROR:
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:52] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:52] Explicit valence for atom # 0 C, 9, is greater than permitted
# RDKit ERROR: [16:04:52] Can't kekulize mol.  Unkekulized atoms: 0 1 2 8 9
# RDKit ERROR:
# RDKit WARNING: [16:04:52] sanitise [16:04:52] 01: [16:04:52] sanitise [16:04:52] 01: [16:04:53] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:53] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:53] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:53] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [16:04:53] 01: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit ERROR: [16:04:53] Aromatic bonds on non aromatic atom 1

# %%
def number_molecules(mols):
    # Adds number to the molecule as an identifier. 
    # This will be written in the .mol2 file.
    for i, mol in enumerate(mols):
        mol.SetProp('_Name', str(i))
    return mols

def parse_molecules(mols):
    # Removes molecules that generate warnings when parsing through RDKit
    # This could lead to incorrect values depending on how the descriptor
    # is calculated.
    working_mols = []
    nonworking_mols = []
    sio = sys.stderr = StringIO()
    for mol in mols:
        Chem.SanitizeMol(mol)
        res = sio.getvalue()
        if 'WARNING' in res:
            nonworking_mols.append(mol)
            print(res)
            # Reset stderr
            sio = sys.stderr = StringIO()
        else:
            working_mols.append(mol)
            sio = sys.stderr = StringIO()
    working_mols = number_molecules(working_mols)
    return working_mols, nonworking_mols

def calculate_descriptors_pandas(mols, check_mols=False):
    # Calculates 2D and 3D descriptors using Mordred.
    # Returns a DataFrame containing descriptors.
    calc = Calculator(descriptors, ignore_3D=False)
    if check_mols:
        mols, _ = parse_molecules(mols)
    df = calc.pandas(working_mols, ipynb=True, quiet=False)
    df.index.name = 'Molecule_Number'
    df['SMILES'] = [Chem.MolToSmiles(m) for m in mols]
    df['RDKit_Molecule'] = mols
    return df

# %%
mols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-92e3ffa5ba71> in <module>
# ----> 1 mols
#
# NameError: name 'mols' is not defined

# %%
df.to_pickle('Calculated_Descriptors.pkl')
